# %% [markdown]
# <a href="https://colab.research.google.com/github/raju2525/BACKLOG-WALLAH-/blob/main/backlog_wallah!.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !rm -rf sample_data/

# %%
# !pip install buildozer
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.9/86.9 kB 2.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.8/3.8 MB 22.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 468.9/468.9 kB 26.8 MB/s eta 0:00:00
# ...

# %%
# !pip install cython

# %%
# !sudo apt install -y git zip unzip openjdk-17-jdk python3-pip autoconf libtool pkg-config zlib1g-dev libncurses5-dev libncursesw5-dev libtinfo5 cmake libffi-dev libssl-dev
# !pip3 install --upgrade Cython==0.29.33 virtualenv  # the --user should be removed if you do this in a v
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# autoconf is already the newest version (2.71-2).
# autoconf set to manually installed.
# pkg-config is already the newest version (0.29.2-1ubuntu3).
# zip is already the newest version (3.0-12build2).
# cmake is already the newest version (3.22.1-1ubuntu1.22.04.1).
# git is already the newest version (1:2.34.1-1ubuntu1.10).
# libncurses5-dev is already the newest version (6.3-2ubuntu0.1).
# libssl-dev is already the newest version (3.0.2-0ubuntu1.12).
# unzip is already the newest version (6.0-26ubuntu3.1).
# zlib1g-dev is already the newest version (1:1.2.11.dfsg-2ubuntu9.2).
# zlib1g-dev set to manually installed.
# The following additional packages will be installed:
#   fonts-dejavu-core fonts-dejavu-extra libatk-wrapper-java
#   libatk-wrapper-java-jni libfontenc1 libice-dev libsm-dev libxkbfile1
#   libxt-dev libxtst6 libxxf86dga1 openjdk-17-jdk-headless openjdk-17-jre
# ...

# %%
# !pip3 install --upgrade Cython==0.29.33 virtualenv

# %%
# !pip install kivymd kivy
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 15.1 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.9/18.9 MB 47.0 MB/s eta 0:00:00
# ...
#   Created wheel for kivymd: filename=kivymd-1.1.1-py3-none-any.whl size=2194078 sha256=d97d7498271018bc58382f5bc02bef0a2875ff242c037b7dcfe2d8881432a2ed
#   Stored in directory: /root/.cache/pip/wheels/12/d9/fa/2df584e3f57d3d9c57adf55edbe7791f7fa97522d1febe8ee0
# Successfully built kivymd
# ...

# %%
# !sudo apt-get install -y \
    python3-pip \
    build-essential \
    git \
    python3 \
    python3-dev \
    ffmpeg \
    libsdl2-dev \
    libsdl2-image-dev \
    libsdl2-mixer-dev \
    libsdl2-ttf-dev \
    libportmidi-dev \
    libswscale-dev \
    libavformat-dev \
    libavcodec-dev \
    zlib1g-dev
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# build-essential is already the newest version (12.9ubuntu3).
# git is already the newest version (1:2.34.1-1ubuntu1.10).
# python3 is already the newest version (3.10.6-1~22.04).
# python3 set to manually installed.
# python3-dev is already the newest version (3.10.6-1~22.04).
# python3-dev set to manually installed.
# zlib1g-dev is already the newest version (1:1.2.11.dfsg-2ubuntu9.2).
# ffmpeg is already the newest version (7:4.4.2-0ubuntu0.22.04.1).
# libavcodec-dev is already the newest version (7:4.4.2-0ubuntu0.22.04.1).
# libavcodec-dev set to manually installed.
# libavformat-dev is already the newest version (7:4.4.2-0ubuntu0.22.04.1).
# libavformat-dev set to manually installed.
# libswscale-dev is already the newest version (7:4.4.2-0ubuntu0.22.04.1).
# libswscale-dev set to manually installed.
# python3-pip is already the newest version (22.0.2+dfsg-1ubuntu0.3).
# ...

# %%
# !pip install kivymd_extensions.akivymd
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.2/56.2 kB 2.0 MB/s eta 0:00:00
# ...

# %%
# !pip install python-for-android
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 522.8/522.8 kB 6.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.9/62.9 kB 4.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for sh: filename=sh-1.14.3-py2.py3-none-any.whl size=39638 sha256=3b5376535b5477889721a4ce52dea450f6ec4a59446e4118e43e4692e4a3435d
#   Stored in directory: /root/.cache/pip/wheels/48/1e/68/186beff3cdcf04ad2a63b3756fd7eaa8d957e538fdc63787f6
# Successfully built sh
# ...
#   Attempting uninstall: sh
#     Found existing installation: sh 2.0.6
#     Uninstalling sh-2.0.6:
#       Successfully uninstalled sh-2.0.6
# ...

# %%
# !sudo apt-get install -y \
    libgstreamer1.0 \
    gstreamer1.0-plugins-base \
    gstreamer1.0-plugins-good
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# Note, selecting 'libgstreamer1.0-dev' for regex 'libgstreamer1.0'
# Note, selecting 'libgstreamer1.0-0' for regex 'libgstreamer1.0'
# libgstreamer1.0-0 is already the newest version (1.20.3-0ubuntu1).
# libgstreamer1.0-0 set to manually installed.
# The following additional packages will be installed:
#   gir1.2-gstreamer-1.0 glib-networking glib-networking-common
#   glib-networking-services gsettings-desktop-schemas gstreamer1.0-x libaa1
#   libcdparanoia0 libdv4 libdw-dev libelf-dev libgstreamer-plugins-good1.0-0
#   libgudev-1.0-0 libproxy1v5 libshout3 libsoup2.4-1 libsoup2.4-common
#   libtag1v5 libtag1v5-vanilla libunwind-dev libv4l-0 libv4lconvert0
#   libvisual-0.4-0 libwavpack1 session-migration
# Suggested packages:
#   gvfs libdv-bin oss-compat gstreamer1.0-doc libvisual-0.4-plugins
# The following NEW packages will be installed:
# ...

# %%
# !sudo apt-get install libffi7 build-essential libsqlite3-dev sqlite3 bzip2 libbz2-dev zlib1g-dev libssl-dev openssl libgdbm-dev libgdbm-compat-dev liblzma-dev libreadline-dev libncursesw5-dev libffi-dev uuid-dev
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# build-essential is already the newest version (12.9ubuntu3).
# bzip2 is already the newest version (1.0.8-5build1).
# bzip2 set to manually installed.
# libbz2-dev is already the newest version (1.0.8-5build1).
# libbz2-dev set to manually installed.
# libffi-dev is already the newest version (3.4.2-4).
# liblzma-dev is already the newest version (5.2.5-2ubuntu1).
# liblzma-dev set to manually installed.
# libreadline-dev is already the newest version (8.1.2-1).
# libreadline-dev set to manually installed.
# uuid-dev is already the newest version (2.37.2-4ubuntu3).
# uuid-dev set to manually installed.
# libncursesw5-dev is already the newest version (6.3-2ubuntu0.1).
# libsqlite3-dev is already the newest version (3.37.2-2ubuntu0.1).
# libsqlite3-dev set to manually installed.
# libssl-dev is already the newest version (3.0.2-0ubuntu1.12).
# ...

# %%
# !sudo apt-get install build-essential python-dev
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# Package python-dev is not available, but is referred to by another package.
# This may mean that the package is missing, has been obsoleted, or
# is only available from another source
# However the following packages replace it:
#   python2-dev python2 python-dev-is-python3
#
# E: Package 'python-dev' has no installation candidate

# %%
# !sudo apt-get install build-essential libsqlite3-dev sqlite3 bzip2 libbz2-dev zlib1g-dev libssl-dev openssl libgdbm-dev libgdbm-compat-dev liblzma-dev libreadline-dev libncursesw5-dev libffi-dev uuid-dev libffi7
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# build-essential is already the newest version (12.9ubuntu3).
# bzip2 is already the newest version (1.0.8-5build1).
# libbz2-dev is already the newest version (1.0.8-5build1).
# libffi-dev is already the newest version (3.4.2-4).
# libgdbm-compat-dev is already the newest version (1.23-1).
# libgdbm-dev is already the newest version (1.23-1).
# liblzma-dev is already the newest version (5.2.5-2ubuntu1).
# libreadline-dev is already the newest version (8.1.2-1).
# uuid-dev is already the newest version (2.37.2-4ubuntu3).
# libffi7 is already the newest version (3.3-5ubuntu1).
# libncursesw5-dev is already the newest version (6.3-2ubuntu0.1).
# libsqlite3-dev is already the newest version (3.37.2-2ubuntu0.1).
# libssl-dev is already the newest version (3.0.2-0ubuntu1.12).
# openssl is already the newest version (3.0.2-0ubuntu1.12).
# ...

# %%
# !sudo apt-get install libffi-dev
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# libffi-dev is already the newest version (3.4.2-4).
# 0 upgraded, 0 newly installed, 0 to remove and 17 not upgraded.

# %%
# !yes | buildozer android clean

# %%
# !yes | buildozer init
# Out:
# Buildozer is running as root!
# This is not recommended, and may lead to problems later.
# Are you sure you want to continue [y/n]? File buildozer.spec created, ready to customize!

# %%
# !yes | buildozer -v android debug
# Out:
# # Check configuration tokens
# Buildozer is running as root!
# This is not recommended, and may lead to problems later.
# Are you sure you want to continue [y/n]? # Ensure build layout
# # Check configuration tokens
# # Preparing build
# # Check requirements for android
# # Search for Git (git)
# #  -> found at /usr/bin/git
# # Search for Cython (cython)
# #  -> found at /usr/local/bin/cython
# # Search for Java compiler (javac)
# #  -> found at /usr/lib/jvm/java-17-openjdk-amd64/bin/javac
# # Search for Java keytool (keytool)
# #  -> found at /usr/lib/jvm/java-17-openjdk-amd64/bin/keytool
# # Install platform
# # Run ['git', 'config', '--get', 'remote.origin.url']
# # Cwd /content/.buildozer/android/platform/python-for-android
# https://github.com/kivy/python-for-android.git
# # Run ['git', 'branch', '-vv']
# # Cwd /content/.buildozer/android/platform/python-for-android
# ...

# %%
# !yes | buildozer -v android release
# Out:
# # Check configuration tokens
# Buildozer is running as root!
# This is not recommended, and may lead to problems later.
# Are you sure you want to continue [y/n]? # Ensure build layout
# # Check configuration tokens
# # Preparing build
# # Check requirements for android
# # Search for Git (git)
# #  -> found at /usr/bin/git
# # Search for Cython (cython)
# #  -> found at /usr/local/bin/cython
# # Search for Java compiler (javac)
# #  -> found at /usr/lib/jvm/java-17-openjdk-amd64/bin/javac
# # Search for Java keytool (keytool)
# #  -> found at /usr/lib/jvm/java-17-openjdk-amd64/bin/keytool
# # Install platform
# # Run ['git', 'config', '--get', 'remote.origin.url']
# # Cwd /content/.buildozer/android/platform/python-for-android
# https://github.com/kivy/python-for-android.git
# # Run ['git', 'branch', '-vv']
# # Cwd /content/.buildozer/android/platform/python-for-android
# * master e155baf9 [origin/master] Merge pull request #2891 from misl6/release-2023.09.16
# ...

# %%
# !keytool -genkey -v -keystore ~/keystores/bwkey.keystore -alias bwalias -keyalg RSA -keysize 2048 -validity 10000
# Out:
# Enter keystore password:
# Re-enter new password:
# What is your first and last name?
#   [Unknown]:  RAJU BANDAM
# What is the name of your organizational unit?
#   [Unknown]:  BW
# What is the name of your organization?
#   [Unknown]:  RAJ_DEV
# What is the name of your City or Locality?
#   [Unknown]:  HYDERABAD
# What is the name of your State or Province?
#   [Unknown]:  TELANGANA
# What is the two-letter country code for this unit?
#   [Unknown]:  IN
# Is CN=RAJU BANDAM, OU=BW, O=RAJ_DEV, L=HYDERABAD, ST=TELANGANA, C=IN correct?
#   [no]:  yes
#
# Generating 2,048 bit RSA key pair and self-signed certificate (SHA256withRSA) with a validity of 10,000 days
# 	for: CN=RAJU BANDAM, OU=BW, O=RAJ_DEV, L=HYDERABAD, ST=TELANGANA, C=IN
# [Storing /root/keystores/bwkey.keystore]
# keytool error: java.io.FileNotFoundException: /root/keystores/bwkey.keystore (No such file or directory)
# java.io.FileNotFoundException: /root/keystores/bwkey.keystore (No such file or directory)
# ...
